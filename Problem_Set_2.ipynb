# %% [markdown]
# # Problem Set 2
#
# Many of the concepts needed to complete this homework are introduced in the recitation notebooks and the python tutorials.

# %%
# Import the packages and libraries you will use here
from pandas.plotting import scatter_matrix
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1
# This exercise relates to the College data set, which can be found in the file College.csv. It contains a number of variables for 777 different universities and colleges in the US. The variables are
# * Private : Public/private indicator
# * Apps : Number of applications received
# * Accept : Number of applicants accepted
# * Enroll : Number of new students enrolled
# * Top10perc : New students from top 10 % of high school class
# * Top25perc : New students from top 25 % of high school class
# * F.Undergrad : Number of full-time undergraduates
# * P.Undergrad : Number of part-time undergraduates
# * Outstate : Out-of-state tuition
# * Room.Board : Room and board costs
# * Books : Estimated book costs
# * Personal : Estimated personal spending
# * PhD : Percent of faculty with Ph.D.’s
# * Terminal : Percent of faculty with terminal degree
# * S.F.Ratio : Student/faculty ratio
# * perc.alumni : Percent of alumni who donate
# * Expend : Instructional expenditure per student
# * Grad.Rate : Graduation rate
# Before reading the data into python, it can be viewed in Excel or a text editor is well.

# %% [markdown]
# ### (a)
# Use the pandas read_csv() function to read the data into python. Call the loaded data df. Make sure that you have the directory set to the correct location for the data or use the absolute filepath so the program knows where to look for the file. Use `head` and `tail` to show the first 10 and last 10 observations of the data,the default is five so you will need to add an argument for the number of rows.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/Machine Learning/ECON 484/datasets/col.csv')

# %%
df.head(10)
# Out:
#                      Unnamed: 0 Private  Apps  ...  perc.alumni  Expend  Grad.Rate
# 0  Abilene Christian University     Yes  1660  ...           12    7041         60
# 1            Adelphi University     Yes  2186  ...           16   10527         56
# 2                Adrian College     Yes  1428  ...           30    8735         54
# 3           Agnes Scott College     Yes   417  ...           37   19016         59
# 4     Alaska Pacific University     Yes   193  ...            2   10922         15
# 5             Albertson College     Yes   587  ...           11    9727         55
# 6       Albertus Magnus College     Yes   353  ...           26    8861         63
# 7                Albion College     Yes  1899  ...           37   11487         73
# 8              Albright College     Yes  1038  ...           23   11644         80
# 9     Alderson-Broaddus College     Yes   582  ...           15    8991         52
#
# [10 rows x 19 columns]

# %%
df.tail(10)
# Out:
#                           Unnamed: 0 Private  ...  Expend  Grad.Rate
# 767              Winthrop University      No  ...    6729         59
# 768       Wisconsin Lutheran College     Yes  ...    8960         50
# 769            Wittenberg University     Yes  ...   10414         78
# 770                  Wofford College     Yes  ...    7875         75
# 771  Worcester Polytechnic Institute     Yes  ...   10774         82
# 772          Worcester State College      No  ...    4469         40
# 773                Xavier University     Yes  ...    9189         83
# 774   Xavier University of Louisiana     Yes  ...    8323         49
# 775                  Yale University     Yes  ...   40386         99
# 776     York College of Pennsylvania     Yes  ...    4509         99
#
# [10 rows x 19 columns]

# %% [markdown]
# ### (b)
# Read in the data again this time calling the data college and using the parameter index_col=0 in the read_csv function. Notice the difference between the index used when the dataframe is displayed.

# %%
college = pd.read_csv('/content/drive/MyDrive/Machine Learning/ECON 484/datasets/col.csv',index_col = 0)

# %%
college.head(10)
# Out:
#                              Private  Apps  ...  Expend  Grad.Rate
# Abilene Christian University     Yes  1660  ...    7041         60
# Adelphi University               Yes  2186  ...   10527         56
# Adrian College                   Yes  1428  ...    8735         54
# Agnes Scott College              Yes   417  ...   19016         59
# Alaska Pacific University        Yes   193  ...   10922         15
# Albertson College                Yes   587  ...    9727         55
# Albertus Magnus College          Yes   353  ...    8861         63
# Albion College                   Yes  1899  ...   11487         73
# Albright College                 Yes  1038  ...   11644         80
# Alderson-Broaddus College        Yes   582  ...    8991         52
#
# [10 rows x 18 columns]

# %%
college.tail(10)
# Out:
#                                 Private   Apps  ...  Expend  Grad.Rate
# Winthrop University                  No   2320  ...    6729         59
# Wisconsin Lutheran College          Yes    152  ...    8960         50
# Wittenberg University               Yes   1979  ...   10414         78
# Wofford College                     Yes   1501  ...    7875         75
# Worcester Polytechnic Institute     Yes   2768  ...   10774         82
# Worcester State College              No   2197  ...    4469         40
# Xavier University                   Yes   1959  ...    9189         83
# Xavier University of Louisiana      Yes   2097  ...    8323         49
# Yale University                     Yes  10705  ...   40386         99
# York College of Pennsylvania        Yes   2989  ...    4509         99
#
# [10 rows x 18 columns]

# %% [markdown]
# ### (c)
# Now we will do some prelimainary analysis and visualizations of the data that was loaded
# $\mathbf{i)}$ Use the describe method of the dataframe object that you made by reading in the data to show the summary statistics of each of the columns

# %%
df.describe()
# Out:
#                Apps        Accept  ...        Expend  Grad.Rate
# count    777.000000    777.000000  ...    777.000000  777.00000
# mean    3001.638353   2018.804376  ...   9660.171171   65.46332
# std     3870.201484   2451.113971  ...   5221.768440   17.17771
# min       81.000000     72.000000  ...   3186.000000   10.00000
# 25%      776.000000    604.000000  ...   6751.000000   53.00000
# 50%     1558.000000   1110.000000  ...   8377.000000   65.00000
# 75%     3624.000000   2424.000000  ...  10830.000000   78.00000
# max    48094.000000  26330.000000  ...  56233.000000  118.00000
#
# [8 rows x 17 columns]

# %% [markdown]
# $\mathbf{ii)}$ Use the scatter_matrix function that was imported from pandas to produce scatter plots of the pairwise combinations of 6 of the variables of your choice. Adjust the figsize argument make the displayed plots more readable and understandable.

# %%
scatter1 = df[['Accept','Enroll','PhD','Grad.Rate','Outstate','Books']]

scatter_matrix(scatter1,figsize=(20,20),grid=True)

plt.tight_layout(pad=1.08, h_pad=2,w_pad=2, rect=(1,1,2,2)) 

plt.show()

# %% [markdown]
# $\mathbf{iii)}$ Use seaborn's or matplotlib's boxplot function to create a boxplot of Outstate on private.
# Hint: You can either pass in the columns as objects or the names of the columns and use data=college as a parameter

# %%
sns.boxplot(x='Outstate',y='Private', data=df)

# %% [markdown]
# $\mathbf{iv)}$  Create a new qualitative variable in the dataframe, called Elite, by binning the Top10perc variable. We are going to divide universities into two groups based on whether or not the number of students coming from the top 10% of their high school classes exceeds 50.

# %%
df['Top10perc']
# Out:
# 0      23
# 1      16
# 2      22
# 3      60
# 4      16
#        ..
# 772     4
# 773    24
# 774    34
# 775    95
# 776    28
# Name: Top10perc, Length: 777, dtype: int64

# %%
df['Elite'] = 0

df.loc[df.Top10perc > 50, 'Elite'] = 1
df.head()
# Out:
#                      Unnamed: 0 Private  Apps  ...  Expend  Grad.Rate  Elite
# 0  Abilene Christian University     Yes  1660  ...    7041         60      0
# 1            Adelphi University     Yes  2186  ...   10527         56      0
# 2                Adrian College     Yes  1428  ...    8735         54      0
# 3           Agnes Scott College     Yes   417  ...   19016         59      1
# 4     Alaska Pacific University     Yes   193  ...   10922         15      0
#
# [5 rows x 20 columns]

# %% [markdown]
# Get a count of how many universities are in the 'Elite' category. Now make boxplot of Outstate on Elite.

# %%
df['Elite'] = 'No'

df.loc[df.Top10perc > 50, 'Elite'] = 'Yes'
counter = 0
for i in df['Elite']:
  if i == 'Yes':
    counter += 1
print("There are " + str(counter) + " universities in the 'Elite' category.")


sns.boxplot(x='Outstate',y='Elite', data=df)
# Out:
# There are 78 universities in the 'Elite' category.

# %% [markdown]
# $\mathbf{v)}$ Use seaborn's distplot function to produce some histograms with differing numbers of bins for a quantitative variable of your choice. You can make multiple cells or if you are familiar with python try making a grid of multiple plots to be displayed by one cell.

# %%
sns.histplot(x='Top10perc', data = df, color = 'pink', bins = 10)
plt.subplots()
sns.histplot(x='Top10perc', data = df, color = 'Red', bins = 20)
plt.subplots()
sns.histplot(x='Top10perc', data = df, color = 'Blue', bins = 30)

# %% [markdown]
# You can create a grid of histograms with the hist method of the dataframe. Choose some variables that seem interesting and create hhistograms in this way.

# %%
df.hist('Top10perc', bins= 20)
df.hist('Top25perc', bins = 30)
df.hist('Accept', bins = 100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2b5cfd8cc0>]],
#       dtype=object)

# %% [markdown]
# Using the tools that were introduced and/or other ones you find, continue exploring the data set and write a brief summary of what you find. This should involve something you do that was not a part of the previous responses.
# We are not looking for anything in particular just try to make something that shows something about the data ond its relationships in graphs or summary statistics that you haven't already created above.

# %%
df
# Out:
#                          Unnamed: 0 Private   Apps  ...  Expend  Grad.Rate  Elite
# 0      Abilene Christian University     Yes   1660  ...    7041         60     No
# 1                Adelphi University     Yes   2186  ...   10527         56     No
# 2                    Adrian College     Yes   1428  ...    8735         54     No
# 3               Agnes Scott College     Yes    417  ...   19016         59    Yes
# 4         Alaska Pacific University     Yes    193  ...   10922         15     No
# ..                              ...     ...    ...  ...     ...        ...    ...
# 772         Worcester State College      No   2197  ...    4469         40     No
# 773               Xavier University     Yes   1959  ...    9189         83     No
# 774  Xavier University of Louisiana     Yes   2097  ...    8323         49     No
# 775                 Yale University     Yes  10705  ...   40386         99    Yes
# 776    York College of Pennsylvania     Yes   2989  ...    4509         99     No
#
# [777 rows x 20 columns]

# %%
sns.scatterplot(x = 'Top10perc', y = 'Outstate', color = 'purple', data = df)
plt.title('Percent of Top Ten Students and Out-of-State Tuition')
column_1 = df['Top10perc']
column_2 = df['Outstate']
correlation = column_1.corr(column_2)
correlation = str(round(correlation,2))
print("The correlation coefficient between 'Top10perc' and 'Outstate' is " +str(correlation))
# Out:
# The correlation coefficient between 'Top10perc' and 'Outstate' is 0.56

# %% [markdown]
# Explain what you did and what it means here

# %% [markdown]
# I created a scatter plot that displays the relationship between the percentage of students in the top ten percent of their class and the out-of-sttate tuition charged. I also display the correlation coefficient and add pretty color to capture you attention.
#
# As shown, there is a postive trend associated with these two variables. As the percent of students who came from the top ten percent increases at a university, the amount of out-of-state tuition charged generally increases.
#
# I hope you like my plot, Logan!

# %% [markdown]
# ## Chapter 3
# $\mathbf{a)}$Load in auto.csv as a dataframe and the produce a grid of the pairwise scatterplots of the variables of the dataframe

# %%
auto = pd.read_csv("/content/drive/MyDrive/Machine Learning/ECON 484/datasets/Auto.csv")
auto['horsepower'] = auto['horsepower'].replace(to_replace=r'?', value=None, regex=False)
auto = auto.dropna()
auto['horsepower'] = auto['horsepower'].astype(float)
scatter_matrix(auto,figsize=(20,20),grid=True)

plt.tight_layout(pad=1.08, h_pad=2,w_pad=2, rect=(1,1,2,2)) 

plt.show()

# %% [markdown]
# $\mathbf{b)}$ Show the correlation matrix. There are several ways to do this but you should be able to find a function that makes it for the numeric variables of a dataframe.

# %%
auto.corr()
# Out:
#                    mpg  cylinders  ...      year    origin
# mpg           1.000000  -0.776260  ...  0.581469  0.563698
# cylinders    -0.776260   1.000000  ... -0.346717 -0.564972
# displacement -0.804443   0.950920  ... -0.369804 -0.610664
# horsepower   -0.777842   0.842826  ... -0.417440 -0.453590
# weight       -0.831739   0.897017  ... -0.307900 -0.581265
# acceleration  0.422297  -0.504061  ...  0.282901  0.210084
# year          0.581469  -0.346717  ...  1.000000  0.184314
# origin        0.563698  -0.564972  ...  0.184314  1.000000
#
# [8 rows x 8 columns]

# %% [markdown]
# $\mathbf{c)}$ Use the statsmodel OLS function to perform a linear regression with mpg as the response and year as a feature (a variable in the regression). Use the summary() method to print the results.

# %%
# fill in the variable names you plan on using in the regression
import statsmodels.api as sm
X = auto.loc[:,['year']]
X = sm.add_constant(X)
y = auto['mpg']
reg_obj = sm.OLS(y,X)
results = reg_obj.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.338
# Model:                            OLS   Adj. R-squared:                  0.336
# Method:                 Least Squares   F-statistic:                     201.8
# Date:                Wed, 10 Feb 2021   Prob (F-statistic):           2.77e-37
# Time:                        04:44:27   Log-Likelihood:                -1297.7
# No. Observations:                 397   AIC:                             2599.
# Df Residuals:                     395   BIC:                             2607.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -70.2001      6.605    -10.628      0.000     -83.186     -57.214
# year           1.2332      0.087     14.205      0.000       1.063       1.404
# ==============================================================================
# Omnibus:                       22.297   Durbin-Watson:                   0.772
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               15.960
# Skew:                           0.379   Prob(JB):                     0.000342
# Kurtosis:                       2.376   Cond. No.                     1.57e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.57e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# Do a linear regression with mpg as the outcome and all other variables except name as the predictors. Comment on the output. For instance:
# i. Is there a relationship between the predictors and the response?
# ii. Which predictors appear to have a statistically significant relationship to the response?
# iii. What does the coefficient for the year variable suggest?

# %%
X = auto.loc[:,[x for x in auto.columns if x not in ('mpg', 'name')]]
X = sm.add_constant(X)
y = auto['mpg']
reg_obj = sm.OLS(y,X)
results = reg_obj.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.822
# Model:                            OLS   Adj. R-squared:                  0.819
# Method:                 Least Squares   F-statistic:                     256.6
# Date:                Wed, 10 Feb 2021   Prob (F-statistic):          1.68e-141
# Time:                        04:44:27   Log-Likelihood:                -1037.1
# No. Observations:                 397   AIC:                             2090.
# Df Residuals:                     389   BIC:                             2122.
# Df Model:                           7
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const          -17.8233      4.641     -3.841      0.000     -26.947      -8.700
# cylinders       -0.4614      0.322     -1.431      0.153      -1.095       0.172
# displacement     0.0198      0.008      2.641      0.009       0.005       0.035
# horsepower      -0.0151      0.014     -1.107      0.269      -0.042       0.012
# weight          -0.0066      0.001    -10.246      0.000      -0.008      -0.005
# acceleration     0.0932      0.098      0.954      0.341      -0.099       0.285
# year             0.7571      0.051     14.918      0.000       0.657       0.857
# origin           1.4247      0.276      5.161      0.000       0.882       1.967
# ==============================================================================
# Omnibus:                       30.155   Durbin-Watson:                   1.294
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               48.432
# Skew:                           0.512   Prob(JB):                     3.04e-11
# Kurtosis:                       4.371   Cond. No.                     8.60e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.6e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# i. There is a meaningful relationship between some of the predictors and the response variable. For example, weight has a negative and statistically significant relationship with MPG. The heavier the car, the less MPG the car gets.
#
# ii. Year, Origin, Weight, and Displacement appear to have a statistically significant relationship.
#
# iii. The newer the car, the more MPG it gets. For example, a 2021 model car will, on average, get more mpg than a 2015 car.

# %% [markdown]
# $\mathbf{d)}$ Use statsmodels' inluence_plot() function to produce diagnostic plots of the linear regression fit. Comment on any problems you see with the fit. Do the residual plots suggest any unusually large outliers? Does the leverage plot identify any observations with unusually high leverage?

# %%
sm.graphics.influence_plot(results)
plt.show()

#Yes, the residual plot suggests several unusually large outlieres. We can see this for those observation or points that are greater than +/- 2.
#Yes, the leverage plot identifies several observations (e.g., #'s 126,336, and 13) that have unusually high leverage.

# %% [markdown]
# $\mathbf{e)}$ Create some polynomial and interaction features from the existing set of variables and fit linear regression models with them. Do any interaction terms appear to be statistically significant? What about polynomial terms?
# A relativley easy way to do this si the use scikit-learn's polynomial features but you can add in interaction and squared columns individually to the dataframe by multiplying columns together.

# %%
auto['interaction'] = auto["weight"]*auto["year"]
auto['polynomial'] = auto["acceleration"]**2
auto.head()
# Out:
#     mpg  cylinders  ...  interaction  polynomial
# 0  18.0          8  ...       245280      144.00
# 1  15.0          8  ...       258510      132.25
# 2  18.0          8  ...       240520      121.00
# 3  16.0          8  ...       240310      144.00
# 4  17.0          8  ...       241430      110.25
#
# [5 rows x 11 columns]

# %%
X = auto.loc[:,[x for x in auto.columns if x not in ('mpg', 'name')]]
X = sm.add_constant(X)
y = auto['mpg']
reg_obj = sm.OLS(y,X)
results = reg_obj.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.854
# Model:                            OLS   Adj. R-squared:                  0.851
# Method:                 Least Squares   F-statistic:                     251.4
# Date:                Wed, 10 Feb 2021   Prob (F-statistic):          1.16e-155
# Time:                        04:44:28   Log-Likelihood:                -997.78
# No. Observations:                 397   AIC:                             2016.
# Df Residuals:                     387   BIC:                             2055.
# Df Model:                           9
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const          -96.8193     14.402     -6.722      0.000    -125.136     -68.503
# cylinders        0.0241      0.298      0.081      0.936      -0.561       0.609
# displacement     0.0048      0.007      0.666      0.506      -0.009       0.019
# horsepower      -0.0391      0.013     -3.036      0.003      -0.064      -0.014
# weight           0.0292      0.005      6.414      0.000       0.020       0.038
# acceleration    -1.9108      0.543     -3.521      0.000      -2.978      -0.844
# year             2.0214      0.170     11.892      0.000       1.687       2.356
# origin           1.0931      0.253      4.316      0.000       0.595       1.591
# interaction     -0.0005      6e-05     -7.715      0.000      -0.001      -0.000
# polynomial       0.0602      0.016      3.869      0.000       0.030       0.091
# ==============================================================================
# Omnibus:                       22.021   Durbin-Watson:                   1.478
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.350
# Skew:                           0.377   Prob(JB):                     1.28e-08
# Kurtosis:                       4.276   Cond. No.                     2.21e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.21e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# It turns out that both the interaction and polynomial terms are statistically significant at the 1% level.

# %% [markdown]
# ## PCA
# In the first cell I have some code which will generate some random data with 500 features and 10000 observations. There will be 3 clusters of groups indicated by the y variable. Use PCA to reduce the dimensionality down to 2 principle components. Sklearn has a PCA and TruncatedSVD object you can use, the difference will just be demeaning the values or not so there shouldn't be a big difference in results from either method.

# %%
from sklearn.datasets import make_blobs
from sklearn.decomposition import PCA

SEED = 123
X, y = make_blobs(n_samples=1000, n_features=5000, cluster_std=90., random_state=SEED)
X.shape
# Out:
# (1000, 5000)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X)
x_scaled = scaler.transform(X)
x_scaled.shape
# Out:
# (1000, 5000)

# %%
pca = PCA(n_components=2)
pca.fit(x_scaled)

x_pca = pca.transform(x_scaled)
print("Original shape: {}".format(str(x_scaled.shape)))
print("Reduced shape: {}".format(str(x_pca.shape)))
# Out:
# Original shape: (1000, 5000)
# Reduced shape: (1000, 2)

# %% [markdown]
# Generate a plot of the 2 principal components that were found. You may find it helpful to combine X and y into a pandas DataFrame object so that it plays mroe nicely with seaborn.

# %%
pc_df = pd.DataFrame(data = x_pca , 
         columns = ['PC1', 'PC2'])
pc_df['Cluster'] = y

# sns.lmplot( x="PC1", y="PC2",
#   data=pc_df, 
#   fit_reg=False, 
#   hue='Cluster',
#   legend=True,
#     scatter_kws={"s": 80}) 

pc_df["Cluster"] = pc_df["Cluster"].astype(int).astype(str)
g = sns.scatterplot(x="PC1", y="PC2",data=pc_df, hue="Cluster")

# %% [markdown]
# ## KMeans

# %% [markdown]
# Perform K-means clustering of the observations with K = 3. How well do the clusters that you obtained in K-means clustering compare to the true class labels? You can use the classifcation report function from skelarn to get some metrics that measure the quality of the model you used.

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import classification_report

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(X)
y_kmeans = kmeans.predict(X)
print("Classification report for K = 3:")
print(classification_report(y_kmeans,y))
# Out:
# Classification report for K = 3:
#               precision    recall  f1-score   support
#
#            0       0.27      0.29      0.28       313
#            1       0.36      0.37      0.36       331
#            2       0.40      0.37      0.38       356
#
#     accuracy                           0.34      1000
#    macro avg       0.34      0.34      0.34      1000
# weighted avg       0.35      0.34      0.35      1000

# %% [markdown]
# With k = 3, our clusters are not very accurate.

# %% [markdown]
# Perform K-means clustering with K = 2. Describe your results.

# %%
kmeans = KMeans(n_clusters=2)
kmeans.fit(X)
y_kmeans = kmeans.predict(X)
print("Classification report for K = 2:")
print(classification_report(y_kmeans,y))
# Out:
# Classification report for K = 2:
#               precision    recall  f1-score   support
#
#            0       0.49      0.41      0.45       396
#            1       0.66      0.36      0.47       604
#            2       0.00      0.00      0.00         0
#
#     accuracy                           0.38      1000
#    macro avg       0.38      0.26      0.30      1000
# weighted avg       0.59      0.38      0.46      1000
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# It appears that fewer clusters improve accuracy.

# %% [markdown]
# Now perform K-means clustering with K = 4, and describe your results.

# %%
kmeans = KMeans(n_clusters=4)
kmeans.fit(X)
y_kmeans = kmeans.predict(X)
print("Classification report for K = 4:")
print(classification_report(y_kmeans,y))
# Out:
# Classification report for K = 4:
#               precision    recall  f1-score   support
#
#            0       0.16      0.42      0.24       130
#            1       0.44      0.41      0.42       356
#            2       0.49      0.45      0.46       364
#            3       0.00      0.00      0.00       150
#
#     accuracy                           0.36      1000
#    macro avg       0.27      0.32      0.28      1000
# weighted avg       0.35      0.36      0.35      1000
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# With K = 4, our results are even less accurate than with K = 3.

# %% [markdown]
# Now perform K-means clustering with K = 3 on the first two principal component score vectors, rather than on the raw data. That is, perform K-means clustering on the 60 × 2 matrix of which the first column is the first principal component score vector, and the second column is the second principal component score vector. Comment on the results.

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(x_pca)
y_kmeans = kmeans.predict(x_pca)
print("Classification report for K = 3 with PCA = 2:")
print(classification_report(y_kmeans,y))
# Out:
# Classification report for K = 3 with PCA = 2:
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97       343
#            1       0.99      0.98      0.98       336
#            2       0.95      0.98      0.96       321
#
#     accuracy                           0.97      1000
#    macro avg       0.97      0.97      0.97      1000
# weighted avg       0.97      0.97      0.97      1000

# %% [markdown]
# The model is near perfect accuracy given the current cluster assignment.

# %% [markdown]
# Using of of sklearn's data scalers, perform K-means clustering with K = 3 on the data after scaling each variable to have standard deviation one. How do these results compare to those obtained in (b)? Explain.

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(x_scaled)
y_kmeans = kmeans.predict(x_scaled)
print("Classification report for K = 3:")
print(classification_report(y_kmeans,y))
# Out:
# Classification report for K = 3:
#               precision    recall  f1-score   support
#
#            0       0.04      0.48      0.07        27
#            1       0.67      0.41      0.51       540
#            2       0.59      0.45      0.51       433
#
#     accuracy                           0.43      1000
#    macro avg       0.43      0.45      0.36      1000
# weighted avg       0.62      0.43      0.50      1000

# %% [markdown]
# With PCA, a simple clustering method is not effective, as the data points are too far apart and mkaing it difficult to cluster appropriately. However, with PCA, the data is reduced while keeping the meaning, making it easier to cluster.

# %% [markdown]
# ## Supervised Machine Learning
# In this problem, you will develop a model to predict whether a given car gets high or low gas mileage based on the `Auto` data set. you should be able to use the same dataframe for the previous problem using the auto dataset here as well or you can load it in and start over if you want to practice

# %%
auto = pd.read_csv("/content/drive/MyDrive/Machine Learning/ECON 484/datasets/Auto.csv")
auto['horsepower'] = auto['horsepower'].replace(to_replace=r'?', value=None, regex=False)
auto = auto.dropna()
auto['horsepower'] = auto['horsepower'].astype(float)

# %% [markdown]
# Calling the functions is similar for all of the functions from sklearn. This is one of the really nice things about the library: if you know how to use one then you know how to use them all. You will be asked to use models we have not deeply discussed in lecture but that will not change the coding aspect of it so you should be able to complete the assignment without knowing what exactly is happening. This is just meant to introduce you to how to use models from scikit-learn so don't worry if this is the case. This is one of the problems with the way a lot of people try to use machine learning so I do not recommend it in the future as predictions from a model you don't understand are probably not very good predictions no matter how good the scoring metrics do.

# %%
# this creates a variable named mpg01 that indicates whetehr or not gas mileage iss above the median of the sample
auto['mpg01'] = auto['mpg'] > auto['mpg'].median()
auto[['mpg01', 'mpg']]
# Out:
#      mpg01   mpg
# 0    False  18.0
# 1    False  15.0
# 2    False  18.0
# 3    False  16.0
# 4    False  17.0
# ..     ...   ...
# 392   True  27.0
# 393   True  44.0
# 394   True  32.0
# 395   True  28.0
# 396   True  31.0
#
# [397 rows x 2 columns]

# %% [markdown]
# Scikit-learn is set up so that if you know how to use one model you know how to use them all. Here is an example of the steps that you will follow in general for classification, like in the following question. A regression problem is with a continuous outcome and classification is with a discrete outcome.
# ```python
# from sklearn.submoodule import Model # import a model from the appropriate submodule of scikit-learn
# model_obj = Model() # create a model object with relevant tuning parameters
# model_obj.fit(X, y) # fit the model to your data
# model_obj.score(X, y) # get a score of how well the model does using a loss function
# ```

# %% [markdown]
# $(a)$ Create an X matrix and a Y vector. The variable you created called `mpg01` will be the y variable.
# Are there any variables that should not be included? Hint: I am aking this because there is a variable that should not be included.

# %%
X = auto.loc[:,[x for x in auto.columns if x not in ('mpg01','mpg','name')]]
y = auto["mpg01"]
print(X)
print(y)
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  year  origin
# 0            8         307.0       130.0    3504          12.0    70       1
# 1            8         350.0       165.0    3693          11.5    70       1
# 2            8         318.0       150.0    3436          11.0    70       1
# 3            8         304.0       150.0    3433          12.0    70       1
# 4            8         302.0       140.0    3449          10.5    70       1
# ..         ...           ...         ...     ...           ...   ...     ...
# 392          4         140.0        86.0    2790          15.6    82       1
# 393          4          97.0        52.0    2130          24.6    82       2
# 394          4         135.0        84.0    2295          11.6    82       1
# 395          4         120.0        79.0    2625          18.6    82       1
# 396          4         119.0        82.0    2720          19.4    82       1
#
# [397 rows x 7 columns]
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 392     True
# 393     True
# 394     True
# 395     True
# 396     True
# Name: mpg01, Length: 397, dtype: bool

# %% [markdown]
# $(b)$ Perform Linear Discriminant Analysis (LDA) on the training data in order to predict `mpg01`. How accurate is the model?

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA 
LDA_model = LDA()
LDA_model.fit(X, y) 
num = LDA_model.score(X, y)
num = str(round(num,4))
print("The answer is " +str(num)+ ".")
# Out:
# The answer is 0.8967.

# %% [markdown]
# $(c)$ Perform Quadratic Discriminant Analysis (QDA) on the training data in order to predict `mpg01`. How accurate is the model?

# %%
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis as QDA 
QDA_model = QDA()
QDA_model.fit(X, y) 
num = QDA_model.score(X, y)
num = str(round(num,4))
print("The answer is " +str(num)+ ".")
# Out:
# The answer is 0.9068.

# %% [markdown]
# $(d)$ Perform logistic regression on the training data in order to predict `mpg01`. How accurate is the model?

# %%
from sklearn.linear_model import LogisticRegression as LogR 
LR_model = LogR()
LR_model.fit(X, y) 
num = LR_model.score(X, y)
num = str(round(num,4))
print("The answer is " +str(num)+ ".")
# Out:
# The answer is 0.8992.

# %% [markdown]
# $(e)$ Perform K-nearest Neighbors on the training data in order to predict `mpg01`. How accurate is the model?
# Which value of K seems to perform the best on this data set?

# %%
from sklearn.neighbors import KNeighborsClassifier as NN 
NN_model = NN(n_neighbors=1)
NN_model.fit(X,y)
num = NN_model.score(X,y) 
print("The answer is " +str(num)+ ".")
print("When the value of K is equal to one, the model appears to perform the best")
# Out:
# The answer is 1.0.
# When the value of K is equal to one, the model appears to perform the best

# %% [markdown]
# $(f)$ Now run a random forest classifier on the data. If you are feeling comfortable with this, you can try different parameters to try and tune the model to give better results. This is not necessary to receive full credit.

# %%
from sklearn.ensemble import RandomForestClassifier as RFC
RFC_model = RFC()
RFC_model.fit(X,y)
num = RFC_model.score(X,y) 
print("The answer is " +str(num)+ ".")
# Out:
# The answer is 1.0.
